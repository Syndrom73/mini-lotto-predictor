# %% [markdown]
# <a href="https://colab.research.google.com/github/Syndrom73/mini-lotto-predictor/blob/main/Mini_Lotto_Trening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA dostępna:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.11.0+cu128
# CUDA dostępna: True
# GPU: Tesla T4

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

REPOSITORY_URL = "https://github.com/Syndrom73/mini-lotto-predictor.git"
REPOSITORY_DIR = "/content/mini-lotto-predictor"

if os.path.isdir(os.path.join(REPOSITORY_DIR, ".git")):
    print("Aktualizuję istniejące repozytorium...")
    # !git -C "$REPOSITORY_DIR" pull
else:
    print("Pobieram repozytorium...")
    # !git clone "$REPOSITORY_URL" "$REPOSITORY_DIR"
# Out:
# Pobieram repozytorium...
# Cloning into '/content/mini-lotto-predictor'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 13.77 KiB | 13.77 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/mini-lotto-predictor

# !python -m pip install -q -r requirements.txt
# Out:
# /content/mini-lotto-predictor

# %%
import torch
import numpy
import pandas
import scipy
import sklearn

print("Wszystkie biblioteki zostały zaimportowane.")
print("PyTorch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# Wszystkie biblioteki zostały zaimportowane.
# PyTorch: 2.11.0+cu128
# CUDA: True

# %%
# %cd /content/mini-lotto-predictor

from mini_lotto_predictor import main

CSV_PATH = "/content/drive/MyDrive/MiniLotto/wyniki-minilotto.csv"
BUNDLE_PATH = "/content/drive/MyDrive/MiniLotto/mini_lotto_bundle.pt"

# None = dzień po dacie ostatniego losowania w pliku CSV
NEXT_DRAW_DATE = None

main(
    csv_path=CSV_PATH,
    next_draw_date=NEXT_DRAW_DATE,
    bundle_path=BUNDLE_PATH,
)
# Out:
# /content/mini-lotto-predictor
# Plik: /content/drive/MyDrive/MiniLotto/wyniki-minilotto.csv
# Pełny snapshot: 7428 losowań
# Ostatni rekord:
#  Numer       Date  L1  L2  L3  L4  L5
#   7428 2026-08-31  37  21   8  15  25
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
# EXPANDING-WINDOW WALK-FORWARD
# ...
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
